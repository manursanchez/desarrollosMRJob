# %% [markdown]
# Ejemplo de patrón de filtrado usando el filtro de Bloom. Éste nos obliga a realizar esta operación en dos pasos: el primero es crear un fichero que almacenará el filtro de Bloom; lo haremos con un bitarray. El segundo paso será pasar por el Map todos los registros, y en base al archivo que contiene el filtro de Bloom seleccionará los posibles positivos o los negativos; aquí dependerá del objetivo de nuestro filtro. La salida del Map será la lista de los registros filtrados.

# %%
# %%writefile construyeFiltro.py
#!/usr/bin/env python

import csv
import mmh3
from bitarray import bitarray

size =   5000000;
bit_array = bitarray(size)
bit_array.setall(0)

#Función para las operaciones hash usando mmh3

def mapf(url): 
    b1 = mmh3.hash(url, 41) % size
    bit_array[b1]=1

    b2 = mmh3.hash(url, 42) % size
    bit_array[b2]=1

    b3 = mmh3.hash(url, 43) % size
    bit_array[b3]=1

    b4 = mmh3.hash(url, 44) % size
    bit_array[b4]=1

    b5 = mmh3.hash(url, 45) % size
    bit_array[b5]=1

    b6 = mmh3.hash(url, 46) % size
    bit_array[b6]=1

    b7 = mmh3.hash(url, 47) % size
    bit_array[b7]=1

#======================================Programa principal======================================

r = csv.reader(open("archivos_datos/FBarchivoAprendizaje.csv")); #Fichero con el que vamos a crear el filtro
for row in r:
    url=row[1]
    mapf(url);
    

f=open("FBcreado.txt","wb") #Creación del fichero binario de filtro de Bloom(FB)
f.write(bit_array)
f.close()
print ("Fichero binario de filtro de Bloom creado correctamente.")
# Out:
# Overwriting construyeFiltro.py

# %%
# !python construyeFiltro.py
# Out:
# Fichero binario de filtro de Bloom creado correctamente.

# %%
# %%writefile fbloom.py
#!/usr/bin/env python
from mrjob.job import MRJob
import csv
import mmh3
from bitarray import bitarray

size =  5000000;
ba=bitarray(size);
ba.setall(0)
f=open("FBcreado.txt","rb")
f.readinto(ba)
f.readlines

class fbloom(MRJob):
        
    def mapper(self,_, line):
        linea=line.split(",")
        #print("La URL es: ", linea[1])
        b1 = mmh3.hash(linea[1], 41) % size
        #print("El calculo de mmh3 para b1 es: ",b1)
        b2 = mmh3.hash(linea[1], 42) % size
        b3 = mmh3.hash(linea[1], 43) % size
        b4 = mmh3.hash(linea[1], 44) % size
        b5 = mmh3.hash(linea[1], 45) % size
        b6 = mmh3.hash(linea[1], 46) % size
        b7 = mmh3.hash(linea[1], 47) % size
        
        """Aplicamos la condición y lanzamos con yield los que la cumplan"""
        if ba[b1]==True and ba[b2]==True and ba[b3]==True and ba[b4]==True and ba[b5]==True and ba[b6]==True and ba[b7]==True:
            yield "Linea seleccionada: ",linea[1]
            
if __name__ == '__main__':
    fbloom.run()
# Out:
# Writing fbloom.py

# %%
# !python fbloom.py archivos_datos/FBarchivoComprobacion.csv
# Out:
# "Linea seleccionada: "	"linkedin.com"
# "Linea seleccionada: "	"paypal.com"
# "Linea seleccionada: "	"imgur.com"
# "Linea seleccionada: "	"google.it"
# "Linea seleccionada: "	"diply.com"
# "Linea seleccionada: "	"google.ca"
# "Linea seleccionada: "	"xhamster.com"
# "Linea seleccionada: "	"amazon.co.uk"
# "Linea seleccionada: "	"bbc.co.uk"
# "Linea seleccionada: "	"163.com"
# "Linea seleccionada: "	"flipkart.com"
# "Linea seleccionada: "	"amazon.in"
# "Linea seleccionada: "	"espn.go.com"
# "Linea seleccionada: "	"adobe.com"
# "Linea seleccionada: "	"wikia.com"
# "Linea seleccionada: "	"xnxx.com"
# "Linea seleccionada: "	"google.nl"
# "Linea seleccionada: "	"google.co.th"
# "Linea seleccionada: "	"slideshare.net"
# "Linea seleccionada: "	"amazonaws.com"
# "Linea seleccionada: "	"globo.com"
# "Linea seleccionada: "	"aol.com"
# "Linea seleccionada: "	"theguardian.com"
# "Linea seleccionada: "	"zillow.com"
# "Linea seleccionada: "	"indeed.com"
# "Linea seleccionada: "	"wordpress.org"
# "Linea seleccionada: "	"thepiratebay.se"
# "Linea seleccionada: "	"livejournal.com"
# "Linea seleccionada: "	"vice.com"
# "Linea seleccionada: "	"gamer.com.tw"
# "Linea seleccionada: "	"usps.com"
# "Linea seleccionada: "	"adplxmd.com"
# "Linea seleccionada: "	"xywy.com"
# "Linea seleccionada: "	"google.com.ph"
# "Linea seleccionada: "	"wow.com"
# "Linea seleccionada: "	"quikr.com"
# "Linea seleccionada: "	"ndtv.com"
# "Linea seleccionada: "	"amazon.es"
# "Linea seleccionada: "	"pandora.com"
# "Linea seleccionada: "	"smzdm.com"
# "Linea seleccionada: "	"reimageplus.com"
# "Linea seleccionada: "	"webssearches.com"
# "Linea seleccionada: "	"bilibili.com"
# "Linea seleccionada: "	"teepr.com"
# "Linea seleccionada: "	"bomb01.com"
# "Linea seleccionada: "	"google.cl"
# "Linea seleccionada: "	"dell.com"
# "Linea seleccionada: "	"39.net"
# "Linea seleccionada: "	"extratorrent.cc"
# "Linea seleccionada: "	"nba.com"
# "Linea seleccionada: "	"spotify.com"
# "Linea seleccionada: "	"time.com"
# "Linea seleccionada: "	"google.cz"
# "Linea seleccionada: "	"onlinesbi.com"
# "Linea seleccionada: "	"photobucket.com"
# "Linea seleccionada: "	"thefreedictionary.com"
# "Linea seleccionada: "	"google.co.il"
# "Linea seleccionada: "	"milliyet.com.tr"
# "Linea seleccionada: "	"ero-advertising.com"
# "Linea seleccionada: "	"marca.com"
# "Linea seleccionada: "	"eksisozluk.com"
# "Linea seleccionada: "	"disqus.com"
# "Linea seleccionada: "	"java.com"
# "Linea seleccionada: "	"free.fr"
# "Linea seleccionada: "	"repubblica.it"
# "Linea seleccionada: "	"liputan6.com"
# "Linea seleccionada: "	"theverge.com"
# "Linea seleccionada: "	"sberbank.ru"
# "Linea seleccionada: "	"doubleclick.com"
# "Linea seleccionada: "	"google.com.vn"
# "Linea seleccionada: "	"shopclues.com"
# "Linea seleccionada: "	"tabelog.com"
# "Linea seleccionada: "	"jqw.com"
# "Linea seleccionada: "	"houzz.com"
# "Linea seleccionada: "	"abcnews.go.com"
# "Linea seleccionada: "	"youtube-mp3.org"
# "Linea seleccionada: "	"woot.com"
# "Linea seleccionada: "	"ehow.com"
# "Linea seleccionada: "	"vnexpress.net"
# "Linea seleccionada: "	"it168.com"
# "Linea seleccionada: "	"subito.it"
# "Linea seleccionada: "	"appledaily.com.tw"
# "Linea seleccionada: "	"torrentz.in"
# "Linea seleccionada: "	"all2lnk.com"
# "Linea seleccionada: "	"nydailynews.com"
# "Linea seleccionada: "	"dianping.com"
# "Linea seleccionada: "	"priceline.com"
# "Linea seleccionada: "	"elmogaz.com"
# "Linea seleccionada: "	"latimes.com"
# "Linea seleccionada: "	"epweike.com"
# "Linea seleccionada: "	"globososo.com"
# "Linea seleccionada: "	"gawker.com"
# "Linea seleccionada: "	"kdnet.net"
# "Linea seleccionada: "	"myfitnesspal.com"
# "Linea seleccionada: "	"smartshopping.com"
# "Linea seleccionada: "	"googleapis.com"
# "Linea seleccionada: "	"williamhill.com"
# "Linea seleccionada: "	"zoho.com"
# "Linea seleccionada: "	"nmisr.com"
# "Linea seleccionada: "	"mercadolibre.com.mx"
# "Linea seleccionada: "	"rockstargames.com"
# "Linea seleccionada: "	"usaa.com"
# "Linea seleccionada: "	"wav.tv"
# "Linea seleccionada: "	"thehindu.com"
# "Linea seleccionada: "	"primewire.ag"
# "Linea seleccionada: "	"www.gov.uk"
# "Linea seleccionada: "	"gofundme.com"
# "Linea seleccionada: "	"fitbit.com"
# "Linea seleccionada: "	"nate.com"
# "Linea seleccionada: "	"cbsnews.com"
# "Linea seleccionada: "	"ticketmaster.com"
# "Linea seleccionada: "	"k618.cn"
# "Linea seleccionada: "	"ted.com"
# "Linea seleccionada: "	"filehippo.com"
# "Linea seleccionada: "	"istartsurf.com"
# "Linea seleccionada: "	"sfgate.com"
# "Linea seleccionada: "	"nhk.or.jp"
# "Linea seleccionada: "	"usmagazine.com"
# "Linea seleccionada: "	"friv.com"
# "Linea seleccionada: "	"entrepreneur.com"
# "Linea seleccionada: "	"abplive.in"
# "Linea seleccionada: "	"bluehost.com"
# "Linea seleccionada: "	"hubspot.com"
# "Linea seleccionada: "	"behance.net"
# "Linea seleccionada: "	"sulekha.com"
# "Linea seleccionada: "	"lequipe.fr"
# "Linea seleccionada: "	"efix.com"
# "Linea seleccionada: "	"webex.com"
# "Linea seleccionada: "	"webcrawler.com"
# "Linea seleccionada: "	"europa.eu"
# "Linea seleccionada: "	"geocities.jp"
# "Linea seleccionada: "	"google.rs"
# "Linea seleccionada: "	"tomshardware.com"
# "Linea seleccionada: "	"mayoclinic.org"
# "Linea seleccionada: "	"as.com"
# "Linea seleccionada: "	"ruten.com.tw"
# "Linea seleccionada: "	"yandex.kz"
# "Linea seleccionada: "	"gyazo.com"
# "Linea seleccionada: "	"mackeeper.com"
# "Linea seleccionada: "	"trovi.com"
# "Linea seleccionada: "	"mihanblog.com"
# "Linea seleccionada: "	"adp.com"
# "Linea seleccionada: "	"novinky.cz"
# "Linea seleccionada: "	"gutefrage.net"
# "Linea seleccionada: "	"mackolik.com"
# "Linea seleccionada: "	"yts.to"
# "Linea seleccionada: "	"netteller.com"
# "Linea seleccionada: "	"sky.com"
# "Linea seleccionada: "	"bidvertiser.com"
# "Linea seleccionada: "	"yodobashi.com"
# "Linea seleccionada: "	"ytimg.com"
# "Linea seleccionada: "	"mynavi.jp"
# "Linea seleccionada: "	"m-w.com"
# "Linea seleccionada: "	"indianrail.gov.in"
# "Linea seleccionada: "	"blogspot.de"
# "Linea seleccionada: "	"superuser.com"
# "Linea seleccionada: "	"padsdel.com"
# "Linea seleccionada: "	"auction.co.kr"
# "Linea seleccionada: "	"xing.com"
# "Linea seleccionada: "	"liveleak.com"
# "Linea seleccionada: "	"104.com.tw"
# "Linea seleccionada: "	"kotaku.com"
# "Linea seleccionada: "	"jumia.com.ng"
# "Linea seleccionada: "	"cbs.com"
# "Linea seleccionada: "	"olx.com.br"
# "Linea seleccionada: "	"track300.com"
# "Linea seleccionada: "	"126.com"
# "Linea seleccionada: "	"cdiscount.com"
# "Linea seleccionada: "	"investopedia.com"
# "Linea seleccionada: "	"sapo.pt"
# "Linea seleccionada: "	"mbc.net"
# "Linea seleccionada: "	"xbox.com"
# "Linea seleccionada: "	"biobiochile.cl"
# "Linea seleccionada: "	"gamespot.com"
# "Linea seleccionada: "	"cisco.com"
# "Linea seleccionada: "	"monster.com"
# "Linea seleccionada: "	"safehomepage.com"
# "Linea seleccionada: "	"tahrirnews.com"
# "Linea seleccionada: "	"histats.com"
# "Linea seleccionada: "	"prntscr.com"
# "Linea seleccionada: "	"terra.com.br"
# "Linea seleccionada: "	"pchome.com.tw"
# "Linea seleccionada: "	"acfun.tv"
# "Linea seleccionada: "	"jcpenney.com"
# "Linea seleccionada: "	"yandex.by"
# "Linea seleccionada: "	"cbc.ca"
# "Linea seleccionada: "	"sfr.fr"
# "Linea seleccionada: "	"blogspot.com.tr"
# "Linea seleccionada: "	"io9.com"
# "Linea seleccionada: "	"mit.edu"
# "Linea seleccionada: "	"am15.net"
# "Linea seleccionada: "	"almasryalyoum.com"
# "Linea seleccionada: "	"ixxx.com"
# "Linea seleccionada: "	"asahi.com"
# "Linea seleccionada: "	"myfreecams.com"
# "Linea seleccionada: "	"livestrong.com"
# "Linea seleccionada: "	"india.com"
# "Linea seleccionada: "	"android.com"
# "Linea seleccionada: "	"blockthis.co.uk"
# "Linea seleccionada: "	"dreamstime.com"
# "Linea seleccionada: "	"freepik.com"
# "Linea seleccionada: "	"free-tv-video-online.info"
# "Linea seleccionada: "	"gumtree.com"
# "Linea seleccionada: "	"sh.st"
# "Linea seleccionada: "	"cpasbien.pw"
# "Linea seleccionada: "	"whitepages.com"
# "Linea seleccionada: "	"yellowpages.com"
# "Linea seleccionada: "	"instructure.com"
# "Linea seleccionada: "	"digg.com"
# "Linea seleccionada: "	"suning.com"
# "Linea seleccionada: "	"ccb.com"
# "Linea seleccionada: "	"wetter.com"
# "Linea seleccionada: "	"cbslocal.com"
# "Linea seleccionada: "	"anitube.se"
# "Linea seleccionada: "	"researchgate.net"
# "Linea seleccionada: "	"folha.uol.com.br"
# "Linea seleccionada: "	"vk.me"
# "Linea seleccionada: "	"himado.in"
# "Linea seleccionada: "	"nownews.com"
# "Linea seleccionada: "	"pagesjaunes.fr"
# "Linea seleccionada: "	"huaban.com"
# "Linea seleccionada: "	"clien.net"
# "Linea seleccionada: "	"lun.com"
# "Linea seleccionada: "	"weather.gov"
# "Linea seleccionada: "	"21cn.com"
# "Linea seleccionada: "	"google.hr"
# "Linea seleccionada: "	"tokopedia.com"
# "Linea seleccionada: "	"4chan.org"
# "Linea seleccionada: "	"itmedia.co.jp"
# "Linea seleccionada: "	"rutor.org"
# "Linea seleccionada: "	"popsugar.com"
# "Linea seleccionada: "	"ebates.com"
# "Linea seleccionada: "	"t-mobile.com"
# "Linea seleccionada: "	"olx.ua"
# "Linea seleccionada: "	"media-fire.org"
# "Linea seleccionada: "	"audible.com"
# "Linea seleccionada: "	"leagueoflegends.com"
# "Linea seleccionada: "	"mapquest.com"
# "Linea seleccionada: "	"1webcatalog.com"
# "Linea seleccionada: "	"sahadan.com"
# "Linea seleccionada: "	"wayfair.com"
# "Linea seleccionada: "	"adme.ru"
# "Linea seleccionada: "	"7769domain.com"
# "Linea seleccionada: "	"focus.cn"
# "Linea seleccionada: "	"informer.com"
# "Linea seleccionada: "	"faithtap.com"
# "Linea seleccionada: "	"farsnews.com"
# "Linea seleccionada: "	"blogspot.ru"
# "Linea seleccionada: "	"hardsextube.com"
# "Linea seleccionada: "	"redfin.com"
# "Linea seleccionada: "	"immobilienscout24.de"
# "Linea seleccionada: "	"emgn.com"
# "Linea seleccionada: "	"gazzetta.it"
# "Linea seleccionada: "	"theblaze.com"
# "Linea seleccionada: "	"masrawy.com"
# "Linea seleccionada: "	"yhd.com"
# "Linea seleccionada: "	"bahn.de"
# "Linea seleccionada: "	"rakuten.ne.jp"
# "Linea seleccionada: "	"amoory.com"
# "Linea seleccionada: "	"google.by"
# "Linea seleccionada: "	"dafont.com"
# "Linea seleccionada: "	"allocine.fr"
# "Linea seleccionada: "	"androidcentral.com"
# "Linea seleccionada: "	"ebay.ca"
# "Linea seleccionada: "	"deadspin.com"
# "Linea seleccionada: "	"thedailybeast.com"
# "Linea seleccionada: "	"how-old.net"
# "Linea seleccionada: "	"123rf.com"
# "Linea seleccionada: "	"howtogeek.com"
# "Linea seleccionada: "	"hilton.com"
# "Linea seleccionada: "	"prothom-alo.com"
# "Linea seleccionada: "	"walgreens.com"
# "Linea seleccionada: "	"forever21.com"
# "Linea seleccionada: "	"xtube.com"
# "Linea seleccionada: "	"2chblog.jp"
# "Linea seleccionada: "	"oyunskor.com"
# "Linea seleccionada: "	"iminent.com"
# "Linea seleccionada: "	"scoop.it"
# "Linea seleccionada: "	"qingdaonews.com"
# "Linea seleccionada: "	"food.com"
# "Linea seleccionada: "	"zara.com"
# "Linea seleccionada: "	"smh.com.au"
# "Linea seleccionada: "	"techradar.com"
# "Linea seleccionada: "	"nbcsports.com"
# "Linea seleccionada: "	"indianexpress.com"
# "Linea seleccionada: "	"sharepoint.com"
# "Linea seleccionada: "	"drom.ru"
# "Linea seleccionada: "	"offpageads.com"
# "Linea seleccionada: "	"typepad.com"
# "Linea seleccionada: "	"adultfriendfinder.com"
# "Linea seleccionada: "	"hatenablog.com"
# "Linea seleccionada: "	"ampclicks.com"
# "Linea seleccionada: "	"prezi.com"
# "Linea seleccionada: "	"marriott.com"
# "Linea seleccionada: "	"nypost.com"
# "Linea seleccionada: "	"alarabiya.net"
# "Linea seleccionada: "	"jobrapido.com"
# "Linea seleccionada: "	"marktplaats.nl"
# "Linea seleccionada: "	"tsite.jp"
# "Linea seleccionada: "	"investing.com"
# "Linea seleccionada: "	"gittigidiyor.com"
# "Linea seleccionada: "	"4399.com"
# "Linea seleccionada: "	"littlethings.com"
# "Linea seleccionada: "	"deezer.com"
# "Linea seleccionada: "	"mediaset.it"
# "Linea seleccionada: "	"linkwithin.com"
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory C:\Users\cyber\AppData\Local\Temp\fbloom.manuel.20201127.191831.596548
# Running step 1 of 1...
# job output is in C:\Users\cyber\AppData\Local\Temp\fbloom.manuel.20201127.191831.596548\output
# Streaming final output from C:\Users\cyber\AppData\Local\Temp\fbloom.manuel.20201127.191831.596548\output...
# Removing temp directory C:\Users\cyber\AppData\Local\Temp\fbloom.manuel.20201127.191831.596548...

# %%
# !python --version
# Out:
# Python 3.7.4
